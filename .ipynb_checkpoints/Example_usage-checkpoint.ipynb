# %% [markdown]
# # How to use mcFano feature selection tool

# %%
import scanpy as sc

from mFFModule_Pval import calc_mod_fanos

# %matplotlib inline
sc.set_figure_params(dpi=100)

# %% [markdown]
# ## Setup adata

# %%
adata = sc.read_10x_h5('../../Data/10k_PBMC_3p_nextgem_Chromium_X_raw_feature_bc_matrix.h5') # read in adata
# Out:
# /Users/emmanueldollinger/miniconda3/envs/FanoFeatureSelection/lib/python3.10/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /Users/emmanueldollinger/miniconda3/envs/FanoFeatureSelection/lib/python3.10/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata.var_names_make_unique()

# %%
adata.layers['counts'] = adata.X.copy()

# %% [markdown]
# ## Checks for adata input

# %% [markdown]
# Default usage: specify adata and layer of counts

# %% [markdown]
# We require filtering genes before usage:

# %%
calc_mod_fanos(adata, layer='counts')
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/dr/316t0vqd63z7qmsd6j37nb8m0000gn/T/ipykernel_80663/164759178.py in <cell line: 1>()
# ----> 1 calc_mod_fanos(adata, layer='counts')
#
# ~/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py in calc_mod_fanos(adata, layer, cv, n_genes_for_PCA, min_fano_cutoff, p_val_cutoff, return_residuals, verbose)
#      78
#      79     ## Create variables
# ---> 80     raw_count_mat, means, variances, g_counts = make_vars_and_QC(adata, layer)
#      81
#      82     tic = time.perf_counter()
#
# ~/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py in make_vars_and_QC(adata, layer)
#     175     ### Check if any means == 0, probably means QC was not done
#     176     if np.any(means == 0):
# --> 177         raise Exception("Zero means were found, run QC steps before calculating mFF.")
#     178     ### Check if integer data was passed, if not probably passed normalized data
#     179
#
# Exception: Zero means were found, run QC steps before calculating mFF.

# %%
sc.pp.filter_cells(adata, min_genes=400)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.shape
# Out:
# (11893, 22300)

# %%
adata.layers['counts'] = adata.X.copy()

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %% [markdown]
# We require passing counts, not normalized data:

# %%
calc_mod_fanos(adata, layer='X')
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/dr/316t0vqd63z7qmsd6j37nb8m0000gn/T/ipykernel_80663/3666372456.py in <cell line: 1>()
# ----> 1 calc_mod_fanos(adata, layer='X')
#
# ~/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py in calc_mod_fanos(adata, layer, cv, n_genes_for_PCA, min_fano_cutoff, p_val_cutoff, return_residuals, verbose)
#      78
#      79     ## Create variables
# ---> 80     raw_count_mat, means, variances, g_counts = make_vars_and_QC(adata, layer)
#      81
#      82     tic = time.perf_counter()
#
# ~/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py in make_vars_and_QC(adata, layer)
#     179
#     180     if any(g_counts.astype(int) != g_counts):
# --> 181         raise Exception("This function takes raw counts, normalized data was passed.")
#     182     return raw_count_mat, means, variances, g_counts
#     183
#
# Exception: This function takes raw counts, normalized data was passed.

# %% [markdown]
# Default scanpy pipeline:

# %%
sc.pp.highly_variable_genes(adata)
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)

# %%
sc.pl.umap(adata, color='leiden')

# %% [markdown]
# Default mcFano usage:

# %%
calc_mod_fanos(adata, layer='counts') # Replace sc.pp.highly_variable_genes(adata) call
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes

# %%
sc.pl.umap(adata, color='leiden')

# %% [markdown]
# ## Advanced usage:

# %% [markdown]
# ### Tool has 3 verbosity levels: none, a little and a lot

# %%
calc_mod_fanos(adata, layer='counts', verbose=0)

# %%
calc_mod_fanos(adata, layer='counts', verbose=1)
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes

# %%
calc_mod_fanos(adata, layer='counts', verbose=2)
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes
# Calculating corrected Fano factors.
# Using a coefficient of variation of 0.5.
# Finished calculating corrected Fano factors for 22300 genes in 2.958514 seconds.
# Setting min_fano to 1.74010412831477
# Calculating p-values.
# Finished calculating p-values for 1115 corrected Fano factors in 1.557589 seconds.
# Setting 1045 genes with p-values below 0.05 and Fano factors above 1.74010412831477 as highly variable.
# Top 100 selected genes:
#  ['AC147651.1' 'ACRBP' 'C1QB' 'C2orf88' 'CAVIN2' 'CCL4' 'CCL5' 'CCL8'
#  'CD79A' 'CDKN1C' 'CLDN5' 'CLEC1B' 'CLIC3' 'CLU' 'CMTM5' 'CST7' 'CTTN'
#  'CXCL10' 'CXCL9' 'DNTT' 'FCGR3A' 'FGFBP2' 'GNG11' 'GNLY' 'GP1BB' 'GP9'
#  'GZMA' 'GZMB' 'GZMH' 'GZMK' 'HBA1' 'HBA2' 'HBG2' 'HIST1H2AC' 'HOPX'
#  'IFI27' 'IGHA1' 'IGHD' 'IGHG1' 'IGHG2' 'IGHG3' 'IGHG4' 'IGHM' 'IGHV3-15'
#  'IGKC' 'IGKV1-39' 'IGKV1-9' 'IGKV4-1' 'IGLC1' 'IGLC2' 'IGLC3' 'IGLC6'
#  'IGLC7' 'IGLV1-44' 'IGLV1-51' 'IGLV2-23' 'IGLV2-8' 'IGLV3-16' 'IGLV3-21'
#  'IGLV6-57' 'IL32' 'IL7R' 'ITGA2B' 'ITM2C' 'JCHAIN' 'KLRB1' 'KLRD1'
#  'KLRF1' 'LCN2' 'LILRA4' 'LYPD2' 'MS4A1' 'MS4A2' 'MYL9' 'MZB1' 'NKG7'
#  'NRGN' 'PDGFA' 'PDZK1IP1' 'PF4' 'PF4V1' 'PPBP' 'PRF1' 'PRG2' 'PTCRA'
#  'PTGDS' 'S100A12' 'S100A8' 'S100A9' 'S100B' 'SPARC' 'SPON2' 'TCL1A'
#  'TMEM40' 'TPSAB1' 'TRDC' 'TREML1' 'TSC22D1' 'TUBB1' 'TXNDC5']

# %% [markdown]
# ### User can pick whether to limit the number of genes called as highly variable:

# %%
calc_mod_fanos(adata, layer='counts', verbose=1, n_genes_for_PCA=400)
# Out:
# Using pvalue cutoff of 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile and top 400 genes for highly variable genes

# %%
adata.var['highly_variable'].sum()
# Out:
# 400

# %% [markdown]
# Note that by default if there is a conflict between the cutoffs and the number of genes requested by the user, the cutoffs win:

# %%
calc_mod_fanos(adata, layer='counts', verbose=1, n_genes_for_PCA=10000)
# Out:
# Using pvalue cutoff of 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile and top 10000 genes for highly variable genes
# /Users/emmanueldollinger/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py:144: UserWarning: Number of genes meeting cutoffs (1045) is lower than user requested genes (10000). Only including genes meeting cutoff in "highly_variable" slot.
#   warnings.warn(f'Number of genes meeting cutoffs ({meets_cutoff.sum()}) is lower than user requested genes ({n_genes_for_PCA}). Only including genes meeting cutoff in "highly_variable" slot.')

# %%
adata.var['highly_variable'].sum()
# Out:
# 1045

# %% [markdown]
# The p value cutoff can be disabled:

# %%
calc_mod_fanos(adata, layer='counts', verbose=1, p_val_cutoff=None)
# Out:
# Only using min fano quantile cutoff of 0.95 for highly variable genes

# %% [markdown]
# We do NOT recommend turning off the p value criterion; however if considering different celltypes, p value cutoff isn't necessary (and can be faster computationally):

# %%
calc_mod_fanos(adata, layer='counts', verbose=2)
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)
# Out:
# Only using pvalue cutoff 0.05 and calculating pvalues for genes with corrected Fano factor that are 0.95 quantile for highly variable genes
# Calculating corrected Fano factors.
# Using a coefficient of variation of 0.5.
# Finished calculating corrected Fano factors for 22300 genes in 2.949560 seconds.
# Setting min_fano to 1.74010412831477
# Calculating p-values.
# Finished calculating p-values for 1115 corrected Fano factors in 1.544485 seconds.
# Setting 1045 genes with p-values below 0.05 and Fano factors above 1.74010412831477 as highly variable.
# Top 100 selected genes:
#  ['AC147651.1' 'ACRBP' 'C1QB' 'C2orf88' 'CAVIN2' 'CCL4' 'CCL5' 'CCL8'
#  'CD79A' 'CDKN1C' 'CLDN5' 'CLEC1B' 'CLIC3' 'CLU' 'CMTM5' 'CST7' 'CTTN'
#  'CXCL10' 'CXCL9' 'DNTT' 'FCGR3A' 'FGFBP2' 'GNG11' 'GNLY' 'GP1BB' 'GP9'
#  'GZMA' 'GZMB' 'GZMH' 'GZMK' 'HBA1' 'HBA2' 'HBG2' 'HIST1H2AC' 'HOPX'
#  'IFI27' 'IGHA1' 'IGHD' 'IGHG1' 'IGHG2' 'IGHG3' 'IGHG4' 'IGHM' 'IGHV3-15'
#  'IGKC' 'IGKV1-39' 'IGKV1-9' 'IGKV4-1' 'IGLC1' 'IGLC2' 'IGLC3' 'IGLC6'
#  'IGLC7' 'IGLV1-44' 'IGLV1-51' 'IGLV2-23' 'IGLV2-8' 'IGLV3-16' 'IGLV3-21'
#  'IGLV6-57' 'IL32' 'IL7R' 'ITGA2B' 'ITM2C' 'JCHAIN' 'KLRB1' 'KLRD1'
#  'KLRF1' 'LCN2' 'LILRA4' 'LYPD2' 'MS4A1' 'MS4A2' 'MYL9' 'MZB1' 'NKG7'
#  'NRGN' 'PDGFA' 'PDZK1IP1' 'PF4' 'PF4V1' 'PPBP' 'PRF1' 'PRG2' 'PTCRA'
#  'PTGDS' 'S100A12' 'S100A8' 'S100A9' 'S100B' 'SPARC' 'SPON2' 'TCL1A'
#  'TMEM40' 'TPSAB1' 'TRDC' 'TREML1' 'TSC22D1' 'TUBB1' 'TXNDC5']

# %%
sc.pl.umap(adata, color='leiden')

# %%
calc_mod_fanos(adata, layer='counts', p_val_cutoff=None, verbose=2)
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)
# Out:
# Only using min fano quantile cutoff of 0.95 for highly variable genes
# Calculating corrected Fano factors.
# Using a coefficient of variation of 0.5.
# Finished calculating corrected Fano factors for 22300 genes in 2.961119 seconds.
# Setting min_fano to 1.74010412831477
# Setting all genes with mcFano > 1.74010412831477 as highly variable.
# Top 100 selected genes:
#  ['AC004554.2' 'AC005697.2' 'AC006372.1' 'AC009075.1' 'AC011997.1'
#  'AC092611.1' 'AC092651.3' 'AC106743.1' 'AC109492.1' 'AC124242.3' 'ADAD2'
#  'AGBL5-AS1' 'AICDA' 'AK5' 'AKAP6' 'AL022323.5' 'AL133330.2' 'AL158071.4'
#  'AL354760.1' 'AL590705.1' 'AL592430.1' 'ALOX12' 'ANKK1' 'AREG' 'ATP7B'
#  'ATP9A' 'BLNK' 'BRI3' 'C1orf229' 'C1orf56' 'CCR6' 'CD19' 'CD6' 'CD68'
#  'CHI3L2' 'CLEC7A' 'CLLU1OS' 'COL1A1' 'CPNE7' 'CYP4F8' 'FCGR2A' 'FLT3LG'
#  'FOXD2-AS1' 'GAPT' 'GATA3' 'GATA3-AS1' 'GBP4' 'GPR171' 'GPR68' 'HPGDS'
#  'IGLV3-19' 'ITK' 'KCNQ2' 'KLHL29' 'LDLRAP1' 'LGALS3' 'LINC00662' 'MPP1'
#  'MYB' 'NAV2-AS3' 'NPDC1' 'OR2G6' 'PDGFB' 'PTGS2' 'PTTG1' 'RDH16' 'RPRML'
#  'RPS27' 'RPS5' 'RPSA' 'S100A10' 'S100P' 'SHISA8' 'SLC11A1' 'SLC1A7'
#  'SLC26A1' 'SNX22' 'ST8SIA1' 'SWAP70' 'TC2N' 'TCHH' 'TMCC2' 'TMPRSS5'
#  'TPD52' 'TRAV13-2' 'TRAV36DV7' 'TRAV4' 'TRAV41' 'TRBV3-1' 'TRBV6-1'
#  'TRGV2' 'TUBB3' 'VLDLR' 'VMP1' 'WDR66' 'WNK3' 'XBP1' 'Z98752.4' 'ZMAT4'
#  'ZNF727']

# %%
sc.pl.umap(adata, color='leiden')

# %%
# ?calc_mod_fanos
# Out:
# Signature:
# calc_mod_fanos(
#     adata: anndata._core.anndata.AnnData,
#     layer: str,
#     cv: Union[bool, float] = 0.5,
#     n_genes_for_PCA: Union[bool, int] = False,
#     min_fano_cutoff: float = 0.95,
#     p_val_cutoff: Union[bool, float] = 0.05,
#     return_residuals: bool = False,
#     verbose: int = 1,
# )
# Docstring:
# Calculate the corrected Fano factor for all genes in the dataset. Mod_Fano column will be added to .var. Highly_variable column will be added to .var based on the n_genes_for_pca and cutoff parameters.
#
# Parameters
# ----------
# adata - adata object containing information about the raw counts and gene names
# layer - String, describing the layer of adata object containing raw counts (pass "X" if raw counts are in adata.X)
# cv - Float, coefficient of variation for the given dataset. If one is not supplied, one will be estimated
# return_df - Bool, if True, the function will return a pandas dataframe of the results.
# n_genes_for_PCA - [Int, Bool], top number of genes to use for PCA, ranked by corrected Fano factor. If False, only use pvalue method.
# p_val_cutoff - [Bool, Float], if a float value is provided, that p-value cutoff will be used to select genes. If False, only use top genes cutoff method.
# min_fano_cutoff - [Bool, Float], calculate p-values for corrected Fano factors greater than min_fano_cutoff quantile.
# verbose - Int, whether to print computations and top 100 genes
# return_residuals - Bool, if True, the function will return a matrix containing the calculated mean-centered corrected Pearson residuals matrix stored in adata.layers['residuals'].
# File:      ~/Documents/Projects/FeatureSelectionMethod/Code/bigsur/mFFModule_Pval.py
# Type:      function

# %% [markdown]
# Package list:

# %%
# !cat environment.yml
# Out:
# name: FanoFeatureSelection
# channels:
#   - anaconda
#   - bioconda
#   - conda-forge
#   - defaults
# dependencies:
#   - _r-mutex=1.0.1=anacondar_1
#   - adjusttext=0.7.3.1=py_1
#   - alabaster=0.7.13=pyhd8ed1ab_0
#   - anndata=0.8.0=pyhd8ed1ab_1
#   - anndata2ri=1.1=pyhdfd78af_0
#   - anyio=3.6.2=pyhd8ed1ab_0
#   - aom=3.5.0=hf0c8a7f_0
#   - applaunchservices=0.3.0=pyhd8ed1ab_2
#   - appnope=0.1.3=pyhd8ed1ab_0
#   - argon2-cffi=21.3.0=pyhd8ed1ab_0
#   - argon2-cffi-bindings=21.2.0=py310h90acd4f_3
#   - arpack=3.7.0=hefb7bc6_2
#   - arrow=1.2.3=pyhd8ed1ab_0
#   - astroid=2.13.3=py310h2ec42d9_0
#   - atomicwrites=1.4.1=pyhd8ed1ab_0
#   - attrs=22.2.0=pyh71513ae_0
#   - autopep8=1.6.0=pyhd8ed1ab_1
#   - babel=2.11.0=pyhd8ed1ab_0
#   - backcall=0.2.0=pyh9f0ad1d_0
#   - backports=1.0=pyhd8ed1ab_3
#   - backports.functools_lru_cache=1.6.4=pyhd8ed1ab_0
#   - beautifulsoup4=4.11.1=pyha770c72_0
#   - binaryornot=0.4.4=py_1
#   - bioconductor-biobase=2.54.0=r41h3be46a4_2
#   - bioconductor-biocgenerics=0.40.0=r41hdfd78af_0
#   - bioconductor-delayedarray=0.20.0=r41h3be46a4_2
#   - bioconductor-genomeinfodb=1.30.1=r41hdfd78af_0
#   - bioconductor-genomeinfodbdata=1.2.7=r41hdfd78af_2
#   - bioconductor-genomicranges=1.46.1=r41h3be46a4_1
#   - bioconductor-iranges=2.28.0=r41h3be46a4_2
#   - bioconductor-matrixgenerics=1.6.0=r41hdfd78af_0
#   - bioconductor-s4vectors=0.32.4=r41h3be46a4_0
#   - bioconductor-singlecellexperiment=1.16.0=r41hdfd78af_0
#   - bioconductor-summarizedexperiment=1.24.0=r41hdfd78af_0
#   - bioconductor-xvector=0.34.0=r41h3be46a4_2
#   - bioconductor-zlibbioc=1.40.0=r41h3be46a4_2
#   - bioinfokit=2.1.0=pyh7cba7a3_0
#   - black=22.10.0=py310h2ec42d9_2
#   - bleach=6.0.0=pyhd8ed1ab_0
#   - blosc=1.21.2=hebb52c4_0
#   - brotli=1.0.9=hb7f2c08_8
#   - brotli-bin=1.0.9=hb7f2c08_8
#   - brotlipy=0.7.0=py310h90acd4f_1005
#   - brunsli=0.1=h046ec9c_0
#   - bwidget=1.9.14=h694c41f_1
#   - bzip2=1.0.8=h0d85af4_4
#   - c-ares=1.18.1=h0d85af4_0
#   - c-blosc2=2.6.1=had5f71b_0
#   - ca-certificates=2022.12.7=h033912b_0
#   - cached-property=1.5.2=hd8ed1ab_1
#   - cached_property=1.5.2=pyha770c72_1
#   - cairo=1.16.0=h904041c_1014
#   - cctools_osx-64=973.0.1=hcc6d90d_11
#   - certifi=2022.12.7=pyhd8ed1ab_0
#   - cffi=1.15.1=py310ha78151a_3
#   - cfitsio=4.2.0=hd56cc12_0
#   - chardet=5.1.0=py310h2ec42d9_0
#   - charls=2.4.1=hf0c8a7f_0
#   - charset-normalizer=2.1.1=pyhd8ed1ab_0
#   - clang=14.0.6=h694c41f_0
#   - clang-14=14.0.6=default_h55ffa42_0
#   - clang_osx-64=14.0.6=h3113cd8_4
#   - clangxx=14.0.6=default_h55ffa42_0
#   - clangxx_osx-64=14.0.6=h6f97653_4
#   - click=8.1.3=unix_pyhd8ed1ab_2
#   - cloudpickle=2.2.1=pyhd8ed1ab_0
#   - colorama=0.4.6=pyhd8ed1ab_0
#   - compiler-rt=14.0.6=h613da45_0
#   - compiler-rt_osx-64=14.0.6=h8d5cb93_0
#   - cookiecutter=2.1.1=pyh6c4a22f_0
#   - cryptography=39.0.0=py310hdd0c95c_0
#   - curl=7.86.0=h581aaea_1
#   - cycler=0.11.0=pyhd8ed1ab_0
#   - cyrus-sasl=2.1.27=hbdf3212_5
#   - cytoolz=0.12.0=py310h90acd4f_1
#   - dask-core=2023.1.0=pyhd8ed1ab_0
#   - dav1d=1.0.0=hac89ed1_1
#   - debugpy=1.6.6=py310h7a76584_0
#   - decorator=5.1.1=pyhd8ed1ab_0
#   - defusedxml=0.7.1=pyhd8ed1ab_0
#   - diff-match-patch=20200713=pyh9f0ad1d_0
#   - dill=0.3.6=pyhd8ed1ab_1
#   - docutils=0.19=py310h2ec42d9_1
#   - dunamai=1.15.0=pyhd8ed1ab_0
#   - entrypoints=0.4=pyhd8ed1ab_0
#   - expat=2.5.0=hf0c8a7f_0
#   - flake8=4.0.1=pyhd8ed1ab_2
#   - flit-core=3.8.0=pyhd8ed1ab_0
#   - font-ttf-dejavu-sans-mono=2.37=hab24e00_0
#   - font-ttf-inconsolata=3.000=h77eed37_0
#   - font-ttf-source-code-pro=2.038=h77eed37_0
#   - font-ttf-ubuntu=0.83=hab24e00_0
#   - fontconfig=2.14.1=h5bb23bf_0
#   - fonts-anaconda=1=h8fa9717_0
#   - fonts-conda-ecosystem=1=0
#   - fonts-conda-forge=1=0
#   - fonttools=4.38.0=py310h90acd4f_1
#   - freetype=2.12.1=h3f81eb7_1
#   - fribidi=1.0.10=hbcb3906_0
#   - fsspec=2023.1.0=pyhd8ed1ab_0
#   - future=0.18.3=pyhd8ed1ab_0
#   - geos=3.11.1=hf0c8a7f_0
#   - get_version=3.5.4=pyhd8ed1ab_0
#   - gettext=0.21.1=h8a4c099_0
#   - gfortran_impl_osx-64=11.3.0=h1f927f5_27
#   - gfortran_osx-64=11.3.0=h18f7dce_0
#   - giflib=5.2.1=hbcb3906_2
#   - git=2.39.1=pl5321h0195497_0
#   - glib=2.74.1=hbc0c0cd_1
#   - glib-tools=2.74.1=hbc0c0cd_1
#   - glpk=4.65=h0f52abe_1004
#   - gmp=6.2.1=h2e338ed_0
#   - graphite2=1.3.13=h2e338ed_1001
#   - gsl=2.7=h93259b0_0
#   - gst-plugins-base=1.21.3=h37e1711_1
#   - gstreamer=1.21.3=h1d18e73_1
#   - h5py=3.8.0=nompi_py310h5555e59_100
#   - harfbuzz=6.0.0=h08f8713_0
#   - hdf5=1.12.2=nompi_h1f71328_100
#   - icu=70.1=h96cf925_0
#   - idna=3.4=pyhd8ed1ab_0
#   - igraph=0.9.10=hb215a4b_0
#   - imagecodecs=2023.1.23=py310h9517954_0
#   - imageio=2.25.0=pyh24c5eb1_0
#   - imagesize=1.4.1=pyhd8ed1ab_0
#   - importlib-metadata=6.0.0=pyha770c72_0
#   - importlib_metadata=6.0.0=hd8ed1ab_0
#   - importlib_resources=5.10.2=pyhd8ed1ab_0
#   - inflection=0.5.1=pyh9f0ad1d_0
#   - intervaltree=3.0.2=py_0
#   - ipykernel=6.15.1=pyh736e0ef_0
#   - ipython=7.33.0=py310h2ec42d9_0
#   - ipython_genutils=0.2.0=py_1
#   - ipywidgets=8.0.2=pyhd8ed1ab_1
#   - isl=0.25=hb486fe8_0
#   - isort=5.11.4=pyhd8ed1ab_1
#   - jaraco.classes=3.2.3=pyhd8ed1ab_0
#   - jedi=0.18.2=pyhd8ed1ab_0
#   - jellyfish=2.2.10=h04f5b5a_1
#   - jemalloc=4.5.0=0
#   - jinja2=3.1.2=pyhd8ed1ab_1
#   - jinja2-time=0.2.0=pyhd8ed1ab_3
#   - joblib=1.2.0=pyhd8ed1ab_0
#   - jpeg=9e=hac89ed1_2
#   - jsonschema=4.17.3=pyhd8ed1ab_0
#   - jupyter_client=7.4.9=pyhd8ed1ab_0
#   - jupyter_core=5.1.5=py310h2ec42d9_0
#   - jupyter_events=0.6.3=pyhd8ed1ab_0
#   - jupyter_server=2.1.0=pyhd8ed1ab_0
#   - jupyter_server_terminals=0.4.4=pyhd8ed1ab_1
#   - jupyterlab_pygments=0.2.2=pyhd8ed1ab_0
#   - jupyterlab_widgets=3.0.5=pyhd8ed1ab_0
#   - jxrlib=1.1=h35c211d_2
#   - keyring=23.13.1=py310h2ec42d9_0
#   - kiwisolver=1.4.4=py310ha23aa8a_1
#   - krb5=1.19.3=hb98e516_0
#   - lazy-object-proxy=1.9.0=py310h90acd4f_0
#   - lcms2=2.14=h29502cd_1
#   - ld64_osx-64=609=hfd63004_11
#   - legacy-api-wrap=1.2=py_0
#   - leidenalg=0.8.10=py310h9d931ec_0
#   - lerc=4.0.0=hb486fe8_0
#   - libaec=1.0.6=hf0c8a7f_1
#   - libavif=0.11.1=he9a59b1_0
#   - libblas=3.9.0=16_osx64_openblas
#   - libbrotlicommon=1.0.9=hb7f2c08_8
#   - libbrotlidec=1.0.9=hb7f2c08_8
#   - libbrotlienc=1.0.9=hb7f2c08_8
#   - libcblas=3.9.0=16_osx64_openblas
#   - libclang=15.0.7=default_h20dc2f0_0
#   - libclang-cpp14=14.0.6=default_h55ffa42_0
#   - libclang13=15.0.7=default_hc4b5f92_0
#   - libcurl=7.86.0=h581aaea_1
#   - libcxx=14.0.6=hccf4f1f_0
#   - libdeflate=1.17=hac1461d_0
#   - libedit=3.1.20191231=h0678c8f_2
#   - libev=4.33=haf1e3a3_1
#   - libffi=3.4.2=h0d85af4_5
#   - libgfortran=5.0.0=11_3_0_h97931a8_27
#   - libgfortran-devel_osx-64=11.3.0=h824d247_27
#   - libgfortran5=11.3.0=h082f757_27
#   - libglib=2.74.1=h4c723e1_1
#   - libiconv=1.17=hac89ed1_0
#   - libjpeg-turbo=2.1.4=hb7f2c08_0
#   - liblapack=3.9.0=16_osx64_openblas
#   - libllvm11=11.1.0=h8fb7429_5
#   - libllvm14=14.0.6=h5b596cc_1
#   - libllvm15=15.0.7=h7001e86_0
#   - libnghttp2=1.51.0=he2ab024_0
#   - libntlm=1.4=h0d85af4_1002
#   - libogg=1.3.4=h35c211d_1
#   - libopenblas=0.3.21=openmp_h429af6e_3
#   - libopus=1.3.1=hc929b4f_1
#   - libpng=1.6.39=ha978bb4_0
#   - libpq=15.1=hb1ae2b1_1
#   - libprotobuf=3.20.2=hbc0c0cd_0
#   - libsodium=1.0.18=hbcb3906_1
#   - libspatialindex=1.9.3=he49afe7_4
#   - libsqlite=3.40.0=ha978bb4_0
#   - libssh2=1.10.0=h47af595_3
#   - libtiff=4.5.0=hee9004a_2
#   - libvorbis=1.3.7=h046ec9c_0
#   - libwebp=1.2.4=h70a068d_1
#   - libwebp-base=1.2.4=h775f41a_0
#   - libxcb=1.13=h0d85af4_1004
#   - libxml2=2.10.3=hb9e07b5_0
#   - libzlib=1.2.13=hfd90126_4
#   - libzopfli=1.0.3=h046ec9c_0
#   - line_profiler=4.0.2=py310hc6ec292_0
#   - llvm-openmp=15.0.7=h61d9ccf_0
#   - llvm-tools=14.0.6=h5b596cc_1
#   - llvmlite=0.39.1=py310h2bfb868_1
#   - locket=1.0.0=pyhd8ed1ab_0
#   - lz4-c=1.9.4=hf0c8a7f_0
#   - make=4.3=h22f3db7_1
#   - markupsafe=2.1.2=py310h90acd4f_0
#   - matplotlib=3.5.2=py310hecd8cb5_0
#   - matplotlib-base=3.5.2=py310h4510841_1
#   - matplotlib-inline=0.1.6=pyhd8ed1ab_0
#   - matplotlib-venn=0.11.7=pyhd8ed1ab_0
#   - mccabe=0.6.1=py_1
#   - metis=5.1.0=h2e338ed_1006
#   - mistune=2.0.4=pyhd8ed1ab_0
#   - mkl=2022.2.1=h44ed08c_16952
#   - more-itertools=9.0.0=pyhd8ed1ab_0
#   - mpc=1.3.1=h81bd1dd_0
#   - mpfr=4.1.0=h0f52abe_1
#   - mpmath=1.2.1=pyhd8ed1ab_0
#   - munkres=1.0.7=py_1
#   - mypy_extensions=0.4.3=py310h2ec42d9_6
#   - mysql-common=8.0.31=hc4b2c72_0
#   - mysql-libs=8.0.31=h8658499_0
#   - natsort=8.2.0=pyhd8ed1ab_0
#   - nbclassic=0.4.8=pyhd8ed1ab_0
#   - nbclient=0.7.2=pyhd8ed1ab_0
#   - nbconvert=7.2.9=pyhd8ed1ab_0
#   - nbconvert-core=7.2.9=pyhd8ed1ab_0
#   - nbconvert-pandoc=7.2.9=pyhd8ed1ab_0
#   - nbformat=5.7.3=pyhd8ed1ab_0
#   - ncurses=6.3=h96cf925_1
#   - nest-asyncio=1.5.6=pyhd8ed1ab_0
#   - networkx=3.0=pyhd8ed1ab_0
#   - ninja=1.11.0=h1b54a9f_0
#   - notebook=6.5.2=pyha770c72_1
#   - notebook-shim=0.2.2=pyhd8ed1ab_0
#   - nspr=4.35=hea0b92c_0
#   - nss=3.78=ha8197d3_0
#   - numba=0.56.4=py310h62db5c2_0
#   - numexpr=2.8.3=py310hecf8f37_1
#   - numpy=1.23.5=py310h1b7c290_0
#   - numpydoc=1.5.0=pyhd8ed1ab_0
#   - openjdk=17.0.3=hbc0c0cd_5
#   - openjpeg=2.5.0=h13ac156_2
#   - openssl=3.0.8=hfd90126_0
#   - packaging=23.0=pyhd8ed1ab_0
#   - pandas=1.4.3=py310h3099161_0
#   - pandoc=2.19.2=h694c41f_1
#   - pandocfilters=1.5.0=pyhd8ed1ab_0
#   - pango=1.50.12=hbd9bf65_1
#   - parso=0.8.3=pyhd8ed1ab_0
#   - partd=1.3.0=pyhd8ed1ab_0
#   - pathspec=0.11.0=pyhd8ed1ab_0
#   - patsy=0.5.3=pyhd8ed1ab_0
#   - pcre2=10.40=h1c4e4bc_0
#   - perl=5.32.1=2_h0d85af4_perl5
#   - pexpect=4.8.0=pyh1a96a4e_2
#   - pickleshare=0.7.5=py_1003
#   - pillow=9.4.0=py310hab5364c_0
#   - pip=22.3.1=pyhd8ed1ab_0
#   - pixman=0.40.0=hbcb3906_0
#   - pkgutil-resolve-name=1.3.10=pyhd8ed1ab_0
#   - platformdirs=2.6.2=pyhd8ed1ab_0
#   - pluggy=1.0.0=pyhd8ed1ab_5
#   - ply=3.11=py_1
#   - prometheus_client=0.16.0=pyhd8ed1ab_0
#   - prompt-toolkit=3.0.36=pyha770c72_0
#   - psutil=5.9.4=py310h90acd4f_0
#   - pthread-stubs=0.4=hc929b4f_1001
#   - ptyprocess=0.7.0=pyhd3deb0d_0
#   - pycodestyle=2.8.0=pyhd8ed1ab_0
#   - pycparser=2.21=pyhd8ed1ab_0
#   - pydocstyle=6.3.0=pyhd8ed1ab_0
#   - pyflakes=2.4.0=pyhd8ed1ab_0
#   - pygments=2.14.0=pyhd8ed1ab_0
#   - pylint=2.15.10=pyhd8ed1ab_0
#   - pyls-spyder=0.4.0=pyhd8ed1ab_0
#   - pynndescent=0.5.8=pyh1a96a4e_0
#   - pyobjc-core=9.0=py310h4f19300_0
#   - pyobjc-framework-cocoa=9.0=py310h4f19300_0
#   - pyobjc-framework-coreservices=9.0=py310h90acd4f_0
#   - pyobjc-framework-fsevents=9.0=py310h2ec42d9_0
#   - pyopenssl=23.0.0=pyhd8ed1ab_0
#   - pyparsing=3.0.9=pyhd8ed1ab_0
#   - pyqt=5.15.7=py310h57cebac_0
#   - pyqtwebengine=5.15.7=py310h57cebac_0
#   - pyrsistent=0.19.3=py310h90acd4f_0
#   - pysocks=1.7.1=pyha2e5f31_6
#   - pytables=3.7.0=py310h90ba602_3
#   - python=3.10.8=he7542f4_0_cpython
#   - python-annoy=1.17.1=py310h7a76584_0
#   - python-dateutil=2.8.2=pyhd8ed1ab_0
#   - python-fastjsonschema=2.16.2=pyhd8ed1ab_0
#   - python-igraph=0.9.9=py310h1207af4_0
#   - python-json-logger=2.0.4=pyhd8ed1ab_0
#   - python-lsp-black=1.2.1=pyhd8ed1ab_0
#   - python-lsp-jsonrpc=1.0.0=pyhd8ed1ab_0
#   - python-lsp-server=1.5.0=hd8ed1ab_1
#   - python-lsp-server-base=1.5.0=pyhd8ed1ab_1
#   - python-slugify=7.0.0=pyhd8ed1ab_0
#   - python-tzdata=2022.7=pyhd8ed1ab_0
#   - python.app=1.4=py310he24745e_0
#   - python_abi=3.10=3_cp310
#   - pytoolconfig=1.2.4=pyhd8ed1ab_1
#   - pytorch=1.12.0=cpu_py310h32957a8_2
#   - pytz=2022.7.1=pyhd8ed1ab_0
#   - pytz-deprecation-shim=0.1.0.post0=py310h2ec42d9_3
#   - pywavelets=1.4.1=py310h936d966_0
#   - pyyaml=6.0=py310h90acd4f_5
#   - pyzmq=25.0.0=py310hf615a82_0
#   - qdarkstyle=3.0.3=pyhd8ed1ab_0
#   - qstylizer=0.2.2=pyhd8ed1ab_0
#   - qt-main=5.15.6=h0916ed4_4
#   - qt-webengine=5.15.4=h1d4dd28_3
#   - qtawesome=1.2.2=pyhd8ed1ab_0
#   - qtconsole=5.3.2=pyhd8ed1ab_0
#   - qtconsole-base=5.3.2=pyha770c72_0
#   - qtpy=2.3.0=pyhd8ed1ab_0
#   - r-abind=1.4_5=r41hc72bb7e_1004
#   - r-askpass=1.1=r41h815d134_3
#   - r-assertthat=0.2.1=r41hc72bb7e_3
#   - r-backports=1.4.1=r41h815d134_1
#   - r-base=4.1.3=hf7bdea0_5
#   - r-base64enc=0.1_3=r41h815d134_1005
#   - r-bh=1.81.0_1=r41hc72bb7e_0
#   - r-bit=4.0.5=r41h815d134_0
#   - r-bit64=4.0.5=r41h815d134_1
#   - r-bitops=1.0_7=r41h815d134_1
#   - r-blob=1.2.3=r41hc72bb7e_1
#   - r-boot=1.3_28.1=r41hc72bb7e_0
#   - r-broom=1.0.3=r41hc72bb7e_0
#   - r-bslib=0.4.2=r41hc72bb7e_0
#   - r-cachem=1.0.6=r41h815d134_1
#   - r-callr=3.7.3=r41hc72bb7e_0
#   - r-caret=6.0_93=r41h815d134_1
#   - r-catools=1.18.2=r41h49197e3_1
#   - r-cellranger=1.1.0=r41hc72bb7e_1005
#   - r-class=7.3_21=r41h815d134_0
#   - r-cli=3.6.0=r41h49197e3_0
#   - r-clipr=0.8.0=r41hc72bb7e_1
#   - r-clock=0.6.1=r41h49197e3_1
#   - r-cluster=2.1.4=r41h1e4e481_0
#   - r-codetools=0.2_18=r41hc72bb7e_1
#   - r-colorspace=2.1_0=r41h815d134_0
#   - r-commonmark=1.8.1=r41h815d134_0
#   - r-config=0.3.1=r41hc72bb7e_1
#   - r-cowplot=1.1.1=r41hc72bb7e_1
#   - r-cpp11=0.4.3=r41hc72bb7e_0
#   - r-crayon=1.5.2=r41hc72bb7e_1
#   - r-crosstalk=1.2.0=r41hc72bb7e_1
#   - r-crul=1.3=r41h785f33e_1
#   - r-curl=4.3.3=r41h815d134_1
#   - r-data.table=1.14.6=r41h557251b_0
#   - r-dbi=1.1.3=r41hc72bb7e_1
#   - r-dbplyr=2.3.0=r41hc72bb7e_0
#   - r-deldir=1.0_6=r41h1e4e481_1
#   - r-digest=0.6.31=r41h49197e3_0
#   - r-dplyr=1.0.10=r41h49197e3_1
#   - r-dqrng=0.3.0=r41h49197e3_1
#   - r-dtplyr=1.2.2=r41hc72bb7e_2
#   - r-e1071=1.7_12=r41h49197e3_0
#   - r-ellipsis=0.3.2=r41h815d134_1
#   - r-essentials=4.1=r41hd8ed1ab_2003
#   - r-evaluate=0.20=r41hc72bb7e_0
#   - r-fansi=1.0.4=r41h815d134_0
#   - r-farver=2.1.1=r41h49197e3_1
#   - r-fastmap=1.1.0=r41h49197e3_1
#   - r-fitdistrplus=1.1_8=r41hc72bb7e_1
#   - r-fnn=1.1.3.1=r41h49197e3_1
#   - r-fontawesome=0.5.0=r41hc72bb7e_0
#   - r-forcats=0.5.2=r41hc72bb7e_1
#   - r-foreach=1.5.2=r41hc72bb7e_1
#   - r-foreign=0.8_84=r41h815d134_0
#   - r-forge=0.2.0=r41hc72bb7e_4
#   - r-formatr=1.14=r41hc72bb7e_0
#   - r-fs=1.6.0=r41h49197e3_0
#   - r-future=1.30.0=r41hc72bb7e_0
#   - r-future.apply=1.10.0=r41hc72bb7e_0
#   - r-gargle=1.2.1=r41hc72bb7e_1
#   - r-generics=0.1.3=r41hc72bb7e_1
#   - r-ggplot2=3.4.0=r41hc72bb7e_1
#   - r-ggrepel=0.9.2=r41h49197e3_0
#   - r-ggridges=0.5.4=r41hc72bb7e_1
#   - r-gistr=0.9.0=r41hc72bb7e_1
#   - r-glmnet=4.1_2=r41h1e4e481_1
#   - r-globals=0.16.2=r41hc72bb7e_0
#   - r-glue=1.6.2=r41h815d134_1
#   - r-goftest=1.2_3=r41h815d134_1
#   - r-googledrive=2.0.0=r41hc72bb7e_1
#   - r-googlesheets4=1.0.1=r41h785f33e_1
#   - r-gower=1.0.1=r41h815d134_0
#   - r-gplots=3.1.3=r41hc72bb7e_1
#   - r-gridextra=2.3=r41hc72bb7e_1004
#   - r-gtable=0.3.1=r41hc72bb7e_1
#   - r-gtools=3.9.4=r41h815d134_0
#   - r-hardhat=1.2.0=r41hc72bb7e_1
#   - r-haven=2.5.1=r41h49197e3_0
#   - r-here=1.0.1=r41hc72bb7e_1
#   - r-hexbin=1.28.2=r41h1e4e481_1
#   - r-highr=0.10=r41hc72bb7e_0
#   - r-hms=1.1.2=r41hc72bb7e_1
#   - r-htmltools=0.5.4=r41h49197e3_0
#   - r-htmlwidgets=1.6.1=r41hc72bb7e_0
#   - r-httpcode=0.3.0=r41h694c41f_2
#   - r-httpuv=1.6.8=r41h49197e3_0
#   - r-httr=1.4.4=r41hc72bb7e_1
#   - r-ica=1.0_3=r41hc72bb7e_1
#   - r-ids=1.0.1=r41hc72bb7e_2
#   - r-igraph=1.3.1=r41hd51be07_0
#   - r-ipred=0.9_13=r41h815d134_1
#   - r-irdisplay=1.1=r41hd8ed1ab_1
#   - r-irkernel=1.3.2=r41h785f33e_0
#   - r-irlba=2.3.5.1=r41hce01bf1_0
#   - r-isoband=0.2.7=r41h49197e3_1
#   - r-iterators=1.0.14=r41hc72bb7e_1
#   - r-jquerylib=0.1.4=r41hc72bb7e_1
#   - r-jsonlite=1.8.4=r41h815d134_0
#   - r-kernsmooth=2.23_20=r41hc309deb_1
#   - r-knitr=1.42=r41hc72bb7e_1
#   - r-labeling=0.4.2=r41hc72bb7e_2
#   - r-later=1.3.0=r41hf00d5e6_1
#   - r-lattice=0.20_45=r41h815d134_1
#   - r-lava=1.7.1=r41hc72bb7e_0
#   - r-lazyeval=0.2.2=r41h815d134_3
#   - r-leiden=0.4.3=r41hc72bb7e_1
#   - r-lifecycle=1.0.3=r41hc72bb7e_1
#   - r-listenv=0.9.0=r41hc72bb7e_0
#   - r-lmtest=0.9_40=r41h1e4e481_1
#   - r-lobstr=1.1.2=r41h49197e3_2
#   - r-lsei=1.3_0=r41hcf7530e_2
#   - r-lubridate=1.9.1=r41h815d134_0
#   - r-magrittr=2.0.3=r41h815d134_1
#   - r-maps=3.4.1=r41h815d134_1
#   - r-markdown=1.5=r41hc72bb7e_0
#   - r-mass=7.3_58.2=r41h815d134_0
#   - r-matrix=1.5_3=r41hce01bf1_0
#   - r-matrixstats=0.63.0=r41h815d134_0
#   - r-memoise=2.0.1=r41hc72bb7e_1
#   - r-mgcv=1.8_41=r41h40f944a_0
#   - r-mime=0.12=r41h815d134_1
#   - r-miniui=0.1.1.1=r41hc72bb7e_1003
#   - r-modelmetrics=1.2.2.2=r41h910fb29_2
#   - r-modelr=0.1.10=r41hc72bb7e_0
#   - r-mongolite=2.7.1=r41h815d134_0
#   - r-munsell=0.5.0=r41hc72bb7e_1005
#   - r-nlme=3.1_161=r41h1e4e481_0
#   - r-nnet=7.3_18=r41h815d134_1
#   - r-npsurv=0.5_0=r41hc72bb7e_1
#   - r-numderiv=2016.8_1.1=r41hc72bb7e_4
#   - r-odbc=1.3.4=r41h49197e3_0
#   - r-openssl=2.0.5=r41hfeb9312_0
#   - r-packrat=0.9.0=r41hc72bb7e_0
#   - r-parallelly=1.34.0=r41hc72bb7e_0
#   - r-patchwork=1.1.2=r41hc72bb7e_1
#   - r-pbapply=1.7_0=r41hc72bb7e_0
#   - r-pbdzmq=0.3_9=r41h19f9668_0
#   - r-pillar=1.8.1=r41hc72bb7e_1
#   - r-pkgconfig=2.0.3=r41hc72bb7e_2
#   - r-pki=0.1_12=r41h815d134_0
#   - r-plotly=4.10.1=r41hc72bb7e_0
#   - r-plyr=1.8.8=r41h49197e3_0
#   - r-png=0.1_8=r41hbf2103b_0
#   - r-polyclip=1.10_4=r41h49197e3_0
#   - r-prettyunits=1.1.1=r41hc72bb7e_2
#   - r-proc=1.18.0=r41h9951f98_0
#   - r-processx=3.8.0=r41h815d134_0
#   - r-prodlim=2019.11.13=r41h49197e3_2
#   - r-profvis=0.3.7=r41h815d134_1
#   - r-progress=1.2.2=r41hc72bb7e_3
#   - r-progressr=0.13.0=r41hc72bb7e_0
#   - r-promises=1.2.0.1=r41h49197e3_1
#   - r-proxy=0.4_27=r41h815d134_1
#   - r-pryr=0.1.5=r41h49197e3_1
#   - r-ps=1.7.2=r41h815d134_0
#   - r-purrr=1.0.1=r41h815d134_0
#   - r-quantmod=0.4.20=r41hc72bb7e_1
#   - r-r2d3=0.2.6=r41hc72bb7e_1
#   - r-r6=2.5.1=r41hc72bb7e_1
#   - r-randomforest=4.7_1.1=r41h1e4e481_1
#   - r-rann=2.6.1=r41h49197e3_3
#   - r-rappdirs=0.3.3=r41h815d134_1
#   - r-rbokeh=0.5.2=r41hc72bb7e_2
#   - r-rcolorbrewer=1.1_3=r41h785f33e_1
#   - r-rcpp=1.0.10=r41h49197e3_0
#   - r-rcppannoy=0.0.20=r41h49197e3_0
#   - r-rcpparmadillo=0.11.4.3.1=r41hf5e6a41_0
#   - r-rcppeigen=0.3.3.9.3=r41h4f1a15b_0
#   - r-rcppparallel=5.1.6=r41h49197e3_0
#   - r-rcppprogress=0.4.2=r41hc72bb7e_2
#   - r-rcpptoml=0.1.7=r41h49197e3_2
#   - r-rcurl=1.98_1.9=r41h815d134_1
#   - r-readr=2.1.3=r41h49197e3_1
#   - r-readxl=1.4.1=r41h3ae43e4_1
#   - r-recipes=1.0.4=r41hc72bb7e_0
#   - r-recommended=4.1=r41hd8ed1ab_1005
#   - r-rematch=1.0.1=r41hc72bb7e_1005
#   - r-rematch2=2.1.2=r41hc72bb7e_2
#   - r-repr=1.1.5=r41h785f33e_0
#   - r-reprex=2.0.2=r41hc72bb7e_1
#   - r-reshape2=1.4.4=r41h49197e3_2
#   - r-reticulate=1.27=r41h49197e3_0
#   - r-rgeos=0.6_1=r41h9461dca_0
#   - r-rjava=1.0_6=r41h4348e31_5
#   - r-rjdbc=0.2_10=r41hc72bb7e_1
#   - r-rjson=0.2.21=r41h49197e3_2
#   - r-rjsonio=1.3_1.8=r41h49197e3_0
#   - r-rlang=1.0.6=r41h49197e3_1
#   - r-rmarkdown=2.20=r41hc72bb7e_0
#   - r-rocr=1.0_11=r41hbe3e9c8_2
#   - r-rpart=4.1.19=r41h815d134_0
#   - r-rprojroot=2.0.3=r41hc72bb7e_1
#   - r-rsconnect=0.8.29=r41hc72bb7e_0
#   - r-rspectra=0.16_1=r41h4f1a15b_1
#   - r-rstudioapi=0.14=r41hc72bb7e_1
#   - r-rtsne=0.16=r41h816a2aa_1
#   - r-rvest=1.0.3=r41hc72bb7e_1
#   - r-sass=0.4.5=r41h49197e3_0
#   - r-scales=1.2.1=r41hc72bb7e_1
#   - r-scattermore=0.8=r41h815d134_1
#   - r-sctransform=0.3.5=r41h4f1a15b_1
#   - r-selectr=0.4_2=r41hc72bb7e_2
#   - r-seurat=4.3.0=r41h49197e3_0
#   - r-seuratobject=4.1.3=r41h49197e3_0
#   - r-shape=1.4.6=r41ha770c72_1
#   - r-shiny=1.7.4=r41h785f33e_0
#   - r-sitmo=2.0.2=r41h49197e3_1
#   - r-sourcetools=0.1.7=r41h49197e3_1003
#   - r-sp=1.6_0=r41h815d134_0
#   - r-sparklyr=1.7.9=r41hc72bb7e_0
#   - r-spatial=7.3_16=r41h815d134_0
#   - r-spatstat.data=3.0_0=r41hc72bb7e_0
#   - r-spatstat.explore=3.0_5=r41h815d134_0
#   - r-spatstat.geom=3.0_5=r41h815d134_0
#   - r-spatstat.random=3.1_3=r41h49197e3_0
#   - r-spatstat.sparse=3.0_0=r41h815d134_0
#   - r-spatstat.utils=3.0_1=r41h815d134_0
#   - r-squarem=2021.1=r41hc72bb7e_1
#   - r-stringi=1.7.12=r41h7183e51_0
#   - r-stringr=1.5.0=r41h785f33e_0
#   - r-survival=3.5_0=r41h815d134_0
#   - r-sys=3.4.1=r41h815d134_0
#   - r-tensor=1.5=r41hc72bb7e_1004
#   - r-tibble=3.1.8=r41h815d134_1
#   - r-tidyr=1.3.0=r41h49197e3_0
#   - r-tidyselect=1.2.0=r41hbe3e9c8_0
#   - r-tidyverse=1.3.2=r41hc72bb7e_1
#   - r-timechange=0.2.0=r41h49197e3_0
#   - r-timedate=4022.108=r41hc72bb7e_0
#   - r-tinytex=0.43=r41hc72bb7e_0
#   - r-triebeard=0.3.0=r41h49197e3_1005
#   - r-ttr=0.24.3=r41h815d134_1
#   - r-tzdb=0.3.0=r41h49197e3_1
#   - r-urltools=1.7.3=r41h49197e3_3
#   - r-utf8=1.2.2=r41h815d134_1
#   - r-uuid=1.1_0=r41h815d134_1
#   - r-uwot=0.1.14=r41h49197e3_1
#   - r-vctrs=0.5.2=r41h49197e3_0
#   - r-viridislite=0.4.1=r41hc72bb7e_1
#   - r-vroom=1.6.1=r41h49197e3_0
#   - r-withr=2.5.0=r41hc72bb7e_1
#   - r-xfun=0.36=r41h49197e3_0
#   - r-xml2=1.3.3=r41h3576887_2
#   - r-xtable=1.8_4=r41hc72bb7e_4
#   - r-xts=0.12.2=r41h815d134_0
#   - r-yaml=2.3.7=r41h815d134_0
#   - r-zoo=1.8_11=r41h815d134_1
#   - readline=8.1.2=h3899abd_0
#   - requests=2.28.2=pyhd8ed1ab_0
#   - rfc3339-validator=0.1.4=pyhd8ed1ab_0
#   - rfc3986-validator=0.1.1=pyh9f0ad1d_0
#   - rope=1.6.0=pyhd8ed1ab_0
#   - rpy2=3.5.7=py310r41h936d966_0
#   - rstudio=1.1.456=h04f5b5a_1
#   - rtree=1.0.1=py310had9ce37_1
#   - scanpy=1.8.2=pyhd8ed1ab_0
#   - scikit-image=0.19.3=py310hecf8f37_2
#   - scikit-learn=1.1.2=py310h3ba92a3_0
#   - scipy=1.9.0=py310h70707f4_0
#   - scrublet=0.2.3=pyh5e36f6f_1
#   - seaborn=0.11.2=hd8ed1ab_0
#   - seaborn-base=0.11.2=pyhd8ed1ab_0
#   - send2trash=1.8.0=pyhd8ed1ab_0
#   - setuptools=66.1.1=pyhd8ed1ab_0
#   - sigtool=0.1.3=h88f4db0_0
#   - simplegeneric=0.8.1=py_1
#   - sinfo=0.3.1=py_0
#   - sip=6.6.2=py310hd4537e4_0
#   - six=1.16.0=pyh6c4a22f_0
#   - sleef=3.5.1=h6db0672_2
#   - snappy=1.1.9=h225ccf5_2
#   - sniffio=1.3.0=pyhd8ed1ab_0
#   - snowballstemmer=2.2.0=pyhd8ed1ab_0
#   - sortedcontainers=2.4.0=pyhd8ed1ab_0
#   - soupsieve=2.3.2.post1=pyhd8ed1ab_0
#   - sphinx=6.1.3=pyhd8ed1ab_0
#   - sphinxcontrib-applehelp=1.0.4=pyhd8ed1ab_0
#   - sphinxcontrib-devhelp=1.0.2=py_0
#   - sphinxcontrib-htmlhelp=2.0.0=pyhd8ed1ab_0
#   - sphinxcontrib-jsmath=1.0.1=py_0
#   - sphinxcontrib-qthelp=1.0.3=py_0
#   - sphinxcontrib-serializinghtml=1.1.5=pyhd8ed1ab_2
#   - spyder=5.3.3=py310h2ec42d9_0
#   - spyder-kernels=2.3.3=py310h2ec42d9_0
#   - spyder-line-profiler=0.3.1=pyh6c4a22f_0
#   - sqlite=3.38.5=h707629a_0
#   - statsmodels=0.13.5=py310h936d966_2
#   - stdlib-list=0.8.0=pyhd8ed1ab_0
#   - suitesparse=5.10.1=h7aff33d_1
#   - tabulate=0.9.0=pyhd8ed1ab_1
#   - tapi=1100.0.11=h9ce4665_0
#   - tbb=2021.7.0=hb8565cd_1
#   - terminado=0.17.1=pyhd1c38e8_0
#   - text-unidecode=1.3=py_0
#   - textdistance=4.5.0=pyhd8ed1ab_0
#   - texttable=1.6.7=pyhd8ed1ab_0
#   - textwrap3=0.9.2=py_0
#   - threadpoolctl=3.1.0=pyh8a188c0_0
#   - three-merge=0.1.1=pyh9f0ad1d_0
#   - tifffile=2023.1.23.1=pyhd8ed1ab_0
#   - tinycss2=1.2.1=pyhd8ed1ab_0
#   - tk=8.6.12=h5dbffcc_0
#   - tktable=2.10=h49f0cf7_3
#   - toml=0.10.2=pyhd8ed1ab_0
#   - tomli=2.0.1=pyhd8ed1ab_0
#   - tomlkit=0.11.6=pyha770c72_0
#   - toolz=0.12.0=pyhd8ed1ab_0
#   - tornado=6.2=py310h90acd4f_1
#   - tqdm=4.64.1=pyhd8ed1ab_0
#   - traitlets=5.8.1=pyhd8ed1ab_0
#   - typing=3.10.0.0=pyhd8ed1ab_0
#   - typing-extensions=4.4.0=hd8ed1ab_0
#   - typing_extensions=4.4.0=pyha770c72_0
#   - tzdata=2022g=h191b570_0
#   - tzlocal=4.2=py310h2ec42d9_2
#   - ujson=5.5.0=py310h7a76584_1
#   - umap-learn=0.5.3=py310h2ec42d9_0
#   - uncertainties=3.1.7=pyhd8ed1ab_0
#   - unicodedata2=15.0.0=py310h90acd4f_0
#   - unidecode=1.3.6=pyhd8ed1ab_0
#   - unixodbc=2.3.10=h7b58acd_0
#   - urllib3=1.26.14=pyhd8ed1ab_0
#   - watchdog=2.2.1=py310h389cd99_0
#   - wcwidth=0.2.6=pyhd8ed1ab_0
#   - webencodings=0.5.1=py_1
#   - websocket-client=1.5.0=pyhd8ed1ab_0
#   - whatthepatch=1.0.3=pyhd8ed1ab_0
#   - wheel=0.38.4=pyhd8ed1ab_0
#   - widgetsnbextension=4.0.5=pyhd8ed1ab_0
#   - wrapt=1.14.1=py310h90acd4f_1
#   - wurlitzer=3.0.3=pyhd8ed1ab_0
#   - xorg-libxau=1.0.9=h35c211d_0
#   - xorg-libxdmcp=1.1.3=h35c211d_0
#   - xz=5.2.6=h775f41a_0
#   - yaml=0.2.5=h0d85af4_2
#   - yapf=0.32.0=pyhd8ed1ab_0
#   - zeromq=4.3.4=he49afe7_1
#   - zfp=1.0.0=ha894c9a_3
#   - zipp=3.11.0=pyhd8ed1ab_0
#   - zlib=1.2.13=hfd90126_4
#   - zlib-ng=2.0.6=hac89ed1_0
#   - zstd=1.5.2=hbc0c0cd_6
#   - pip:
#     - pyqt5-sip==12.11.0
# prefix: /Users/emmanueldollinger/miniconda3/envs/FanoFeatureSelection
